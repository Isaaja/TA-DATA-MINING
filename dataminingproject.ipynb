# %% [markdown]
# # **Data Mining Project**
#
# ---

# %% [markdown]
# Import Library yang dibutuhkan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# Import Dataset

# %%
dataset = pd.read_csv("/content/dataset.csv")

# %% [markdown]
# ## Data assessment & preprocessing

# %% [markdown]
# ### Data assessment

# %%
dataset
# Out:
#                         NAMA  Agama  PPKN  MTK  B.Indo  Sejarah  Seni  PJOK  \
# 0           Ahmalludin Aries     84    83   87      79       82    82    80
# 1          ARLIKA MAHMUDAH S     93    80   81     100       95    75    99
# 2         Audrey Novarisandi     85    85   85      82       79    80    85
# 3    Briantama Yusuf Fadilah     85    85   85      83       81    81    85
# 4        Dery Mulyana Candra     85    84   84      83       79    80    85
# ..                       ...    ...   ...  ...     ...      ...   ...   ...
# 331          Rapita Ismawati     98    91   96      85       95    88    79
# 332          Ninda Pritasari     74    98   77      78       94    86    90
# 333        Noneng Ismaryanti     86    93   91      80       94    74    74
# 334          Nadira Al Fitri     85    74   75      92      100    74    84
# 335    Muhammad Akmal Syafiq     93    93   93      87       73    85    90
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NAMA      336 non-null    object
#  1   Agama     336 non-null    int64
#  2   PPKN      336 non-null    int64
#  3   MTK       336 non-null    int64
#  4   B.Indo    336 non-null    int64
#  5   Sejarah   336 non-null    int64
#  6   Seni      336 non-null    int64
#  7   PJOK      336 non-null    int64
#  8   TIK       336 non-null    int64
#  9   Geo       336 non-null    int64
#  10  Sosio     336 non-null    int64
#  11  Eko       336 non-null    int64
#  12  Kimia     336 non-null    int64
#  13  B.Jepang  336 non-null    int64
#  14  PKWU      336 non-null    int64
#  15  Fisika    336 non-null    int64
#  16  Biologi   336 non-null    int64
#  17  Eligible  336 non-null    object
# dtypes: int64(16), object(2)
# memory usage: 47.4+ KB

# %%
dataset.describe()
# Out:
#             Agama        PPKN         MTK      B.Indo     Sejarah        Seni  \
# count  336.000000  336.000000  336.000000  336.000000  336.000000  336.000000
# mean    84.517857   85.919643   84.851190   85.372024   84.657738   84.839286
# std      8.357657    8.524737    8.268364    8.345970    8.607466    8.651688
# min     70.000000   70.000000   70.000000   70.000000   70.000000   70.000000
# 25%     78.000000   79.000000   78.000000   79.000000   79.000000   78.000000
# 50%     85.000000   86.000000   85.000000   85.000000   83.000000   84.000000
# 75%     91.000000   93.000000   92.000000   92.000000   92.000000   92.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#              PJOK         TIK         Geo       Sosio         Eko       Kimia  \
# count  336.000000  336.000000  336.000000  336.000000  336.000000  336.000000
# mean    85.369048   84.467262   84.252976   84.345238   84.217262   85.413690
# ...

# %% [markdown]
# Analisis Statistik untuk semua attribut dataset

# %%
print(dataset.hist())
# Out:
# [[<Axes: title={'center': 'Agama'}> <Axes: title={'center': 'PPKN'}>
#   <Axes: title={'center': 'MTK'}> <Axes: title={'center': 'B.Indo'}>]
#  [<Axes: title={'center': 'Sejarah'}> <Axes: title={'center': 'Seni'}>
#   <Axes: title={'center': 'PJOK'}> <Axes: title={'center': 'TIK'}>]
#  [<Axes: title={'center': 'Geo'}> <Axes: title={'center': 'Sosio'}>
#   <Axes: title={'center': 'Eko'}> <Axes: title={'center': 'Kimia'}>]
#  [<Axes: title={'center': 'B.Jepang'}> <Axes: title={'center': 'PKWU'}>
#   <Axes: title={'center': 'Fisika'}> <Axes: title={'center': 'Biologi'}>]]

# %% [markdown]
# Menjumlah banyak siswa yang termasuk eligible

# %%
print("Daftar Siswa yang Eligible sebanyak = ",(dataset["Eligible"] == "ya").sum())
# Out:
# Daftar Siswa yang Eligible sebanyak =  139

# %% [markdown]
# Menampilkan dataset yang bersifat null atau kosong

# %%
dataset.isna().sum()
# Out:
# NAMA        0
# Agama       0
# PPKN        0
# MTK         0
# B.Indo      0
# Sejarah     0
# Seni        0
# PJOK        0
# TIK         0
# Geo         0
# Sosio       0
# Eko         0
# Kimia       0
# B.Jepang    0
# PKWU        0
# Fisika      0
# Biologi     0
# Eligible    0
# dtype: int64

# %% [markdown]
# Menampilkan baris dan kolom pada data

# %%
dataset.shape
# Out:
# (336, 18)

# %% [markdown]
# Menghapus dataset yang bersifat null atau kosong

# %%
dataset.dropna(axis=0, inplace=True)
dataset.isna().sum()
# Out:
# NAMA        0
# Agama       0
# PPKN        0
# MTK         0
# B.Indo      0
# Sejarah     0
# Seni        0
# PJOK        0
# TIK         0
# Geo         0
# Sosio       0
# Eko         0
# Kimia       0
# B.Jepang    0
# PKWU        0
# Fisika      0
# Biologi     0
# Eligible    0
# dtype: int64

# %%
dataset.shape
# Out:
# (336, 18)

# %% [markdown]
# Menampilkan data duplikat

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Menghapus data duplikat

# %%
dataset.drop_duplicates(inplace=True)
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# Mengganti attribut dataset "Eligible" yang bersifat object menjadi int

# %%
unique_classes = dataset['Eligible'].unique()
print("Data Target : ",unique_classes)
# Out:
# Data Target :  ['tidak' 'ya']

# %% [markdown]
# Mengubah nilai attribut dataset

# %%
dataset["Eligible"]=dataset["Eligible"].replace({'tidak' : 1, 'ya' : 0})
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336 entries, 0 to 335
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NAMA      336 non-null    object
#  1   Agama     336 non-null    int64
#  2   PPKN      336 non-null    int64
#  3   MTK       336 non-null    int64
#  4   B.Indo    336 non-null    int64
#  5   Sejarah   336 non-null    int64
#  6   Seni      336 non-null    int64
#  7   PJOK      336 non-null    int64
#  8   TIK       336 non-null    int64
#  9   Geo       336 non-null    int64
#  10  Sosio     336 non-null    int64
#  11  Eko       336 non-null    int64
#  12  Kimia     336 non-null    int64
#  13  B.Jepang  336 non-null    int64
#  14  PKWU      336 non-null    int64
#  15  Fisika    336 non-null    int64
#  16  Biologi   336 non-null    int64
#  17  Eligible  336 non-null    int64
# dtypes: int64(17), object(1)
# memory usage: 49.9+ KB

# %%
dataset.head(10)
# Out:
#                         NAMA  Agama  PPKN  MTK  B.Indo  Sejarah  Seni  PJOK  \
# 0           Ahmalludin Aries     84    83   87      79       82    82    80
# 1          ARLIKA MAHMUDAH S     93    80   81     100       95    75    99
# 2         Audrey Novarisandi     85    85   85      82       79    80    85
# 3    Briantama Yusuf Fadilah     85    85   85      83       81    81    85
# 4        Dery Mulyana Candra     85    84   84      83       79    80    85
# 5     DESLYNE CAHYA CALLYSTA     85    86   86      83       79    80    85
# 6              EKA HIDAYANTI     85    86   86      83       79    80    82
# 7  Ester Novitasari Sihotang     83    85   85      83       79    80    83
# 8              FAZRI HAYIKAL     85    85   85      84       83    83    85
# 9        Femy Kayla Zhahiyah     85    85   85      84       79    80    83
#
#    TIK  Geo  Sosio  Eko  Kimia  B.Jepang  PKWU  Fisika  Biologi  Eligible
# ...

# %% [markdown]
# Menghapus Data Nama karena data tersebut tidak digunakan dalam pemodelan

# %%
dataset = dataset.drop("NAMA", axis=1)
dataset
# Out:
#      Agama  PPKN  MTK  B.Indo  Sejarah  Seni  PJOK  TIK  Geo  Sosio  Eko  \
# 0       84    83   87      79       82    82    80   84   85     84   84
# 1       93    80   81     100       95    75    99   79   88     80   92
# 2       85    85   85      82       79    80    85   85   81     84   76
# 3       85    85   85      83       81    81    85   85   82     84   76
# 4       85    84   84      83       79    80    85   85   81     85   78
# ..     ...   ...  ...     ...      ...   ...   ...  ...  ...    ...  ...
# 331     98    91   96      85       95    88    79   86   86     77   88
# 332     74    98   77      78       94    86    90   95   86     89   88
# 333     86    93   91      80       94    74    74   72   83     95   87
# 334     85    74   75      92      100    74    84   85   98     81   96
# 335     93    93   93      87       73    85    90   83   71     77   71
#
#      Kimia  B.Jepang  PKWU  Fisika  Biologi  Eligible
# ...

# %% [markdown]
# Menormalisasi Kolom kecuali class atau Outcome / Eligible

# %%
columns_to_normalize=["Agama","PPKN","MTK","B.Indo","Sejarah","Seni","PJOK","TIK","Geo","Sejarah","Sosio","Eko","Kimia","B.Jepang","PKWU","Fisika","Biologi"]
x_data=dataset[columns_to_normalize]
x_data.head()
# Out:
#    Agama  PPKN  MTK  B.Indo  Sejarah  Seni  PJOK  TIK  Geo  Sejarah  Sosio  \
# 0     84    83   87      79       82    82    80   84   85       82     84
# 1     93    80   81     100       95    75    99   79   88       95     80
# 2     85    85   85      82       79    80    85   85   81       79     84
# 3     85    85   85      83       81    81    85   85   82       81     84
# 4     85    84   84      83       79    80    85   85   81       79     85
#
#    Eko  Kimia  B.Jepang  PKWU  Fisika  Biologi
# 0   84     87        77    78      80       86
# 1   92     79        96    75      97       81
# 2   76     85        85    84      77       81
# 3   76     85        85    86      80       80
# 4   78     85        85    85      79       81

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336 entries, 0 to 335
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Agama     336 non-null    int64
#  1   PPKN      336 non-null    int64
#  2   MTK       336 non-null    int64
#  3   B.Indo    336 non-null    int64
#  4   Sejarah   336 non-null    int64
#  5   Seni      336 non-null    int64
#  6   PJOK      336 non-null    int64
#  7   TIK       336 non-null    int64
#  8   Geo       336 non-null    int64
#  9   Sosio     336 non-null    int64
#  10  Eko       336 non-null    int64
#  11  Kimia     336 non-null    int64
#  12  B.Jepang  336 non-null    int64
#  13  PKWU      336 non-null    int64
#  14  Fisika    336 non-null    int64
#  15  Biologi   336 non-null    int64
#  16  Eligible  336 non-null    int64
# dtypes: int64(17)
# memory usage: 47.2 KB

# %% [markdown]
# Membuat range angka menjadi 0 sampai 1

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
x_data_normalized=scaler.fit_transform(x_data)
x_data_normalized=pd.DataFrame(x_data_normalized, columns=columns_to_normalize)

x_data_normalized.head()
# Out:
#       Agama      PPKN       MTK    B.Indo   Sejarah      Seni      PJOK  \
# 0  0.466667  0.433333  0.566667  0.300000  0.400000  0.400000  0.333333
# 1  0.766667  0.333333  0.366667  1.000000  0.833333  0.166667  0.966667
# 2  0.500000  0.500000  0.500000  0.400000  0.300000  0.333333  0.500000
# 3  0.500000  0.500000  0.500000  0.433333  0.366667  0.366667  0.500000
# 4  0.500000  0.466667  0.466667  0.433333  0.300000  0.333333  0.500000
#
#         TIK       Geo   Sejarah     Sosio       Eko     Kimia  B.Jepang  \
# 0  0.466667  0.500000  0.400000  0.466667  0.466667  0.566667  0.233333
# 1  0.300000  0.600000  0.833333  0.333333  0.733333  0.300000  0.866667
# 2  0.500000  0.366667  0.300000  0.466667  0.200000  0.500000  0.500000
# 3  0.500000  0.400000  0.366667  0.466667  0.200000  0.500000  0.500000
# 4  0.500000  0.366667  0.300000  0.500000  0.266667  0.500000  0.500000
#
#        PKWU    Fisika   Biologi
# 0  0.266667  0.333333  0.533333
# 1  0.166667  0.900000  0.366667
# ...

# %% [markdown]
# ## Feature Engineering & data integration

# %% [markdown]
# Feature Engineering

# %% [markdown]
# Membuat Ketentuan Interaksi

# %%
dataset['rata_rata_nilai'] = (dataset['Agama'] + dataset['PPKN'] + dataset['MTK'] + dataset['B.Indo'] + dataset['Sejarah'] + dataset['Seni'] + dataset['PJOK'] + dataset['TIK'] + dataset['Geo'] + dataset['Sosio'] + dataset['Eko'] + dataset['Kimia'] + dataset['B.Jepang'] + dataset['PKWU'] + dataset['Fisika'] + dataset['Biologi']) / (dataset.shape[1]-2)
dataset
# Out:
#      Agama  PPKN  MTK  B.Indo  Sejarah  Seni  PJOK  TIK  Geo  Sosio  Eko  \
# 0       84    83   87      79       82    82    80   84   85     84   84
# 1       93    80   81     100       95    75    99   79   88     80   92
# 2       85    85   85      82       79    80    85   85   81     84   76
# 3       85    85   85      83       81    81    85   85   82     84   76
# 4       85    84   84      83       79    80    85   85   81     85   78
# ..     ...   ...  ...     ...      ...   ...   ...  ...  ...    ...  ...
# 331     98    91   96      85       95    88    79   86   86     77   88
# 332     74    98   77      78       94    86    90   95   86     89   88
# 333     86    93   91      80       94    74    74   72   83     95   87
# 334     85    74   75      92      100    74    84   85   98     81   96
# 335     93    93   93      87       73    85    90   83   71     77   71
#
#      Kimia  B.Jepang  PKWU  Fisika  Biologi  Eligible  rata_rata_nilai
# ...

# %% [markdown]
# ## Visualisasi Data

# %% [markdown]
# Visualisasi data menggunakan pie chart untuk menentukan berapa persen siswa yang termasuk eligible dan tidak

# %%
#pie Chart
gender_counts = dataset["Eligible"].value_counts()
labels = ['TIDAK', 'IYA']
sizes = gender_counts.values
colors = ['lightcoral', 'lightskyblue'] # warna pada pie chart

plt.figure(figsize=(5,5))
plt.pie(gender_counts, labels=labels, colors=colors, autopct= '%1.1f%%', startangle=140)
plt.title('Pie Chart : Eligible')
plt.show()

plt.show()

# %% [markdown]
# Visualisasi data menggunakan count plot

# %%
sns.countplot(x="Eligible", data=dataset)
plt.xticks([0,1],['TIDAK','IYA'])
plt.show() #menampilkan data visual

# %% [markdown]
# ## Modelling menggunakan Decision Tree

# %% [markdown]
# Import Library

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# Membagi kolom - kolom dalam 2 jenis variabel ( dependen dan independen )

# %%
#split dataset in features and target variable
feature_cols = ["Agama","PPKN","MTK","B.Indo","Sejarah","Seni","PJOK","TIK","Geo","Sejarah","Sosio","Eko","Kimia","B.Jepang","PKWU","Fisika","Biologi"]
X = dataset[feature_cols] # Features
y = dataset.Eligible # Target variable

# %% [markdown]
# Membagi dataset menjadi set pelatihan dan set pengujian

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %% [markdown]
# Membangun model Decision Tree

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %% [markdown]
# Hasil Akurasi

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8415841584158416

# %% [markdown]
# ## Uji Performa Model

# %% [markdown]
# Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report # Import library untuk menampilkan Confucion Matrix
import seaborn as sns # Import library visualisasi untuk Confucion Matrix
import matplotlib.pyplot as plt

# Mengitung Confucion Matrix dari hasil testing
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

class_names=['Tidak', 'Iya']
print(classification_report(y_test, y_pred, target_names=class_names))

# Menampilkan Confucion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Tidak       0.81      0.81      0.81        43
#          Iya       0.86      0.86      0.86        58
#
#     accuracy                           0.84       101
#    macro avg       0.84      0.84      0.84       101
# weighted avg       0.84      0.84      0.84       101

# %% [markdown]
# Membuat Visualisasi Decision Tree menggunakan graphviz

# %%
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('diabetes.png')
Image(graph.create_png())
